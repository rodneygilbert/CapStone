# %%
import pandas as pd
import sqlite3
# set connection to SQLite Database
conn = sqlite3.connect("MHPOLL.db")
c = conn.cursor()
# open and read file
df = pd.read_csv('mhpoll.csv')
# print(a1)
df.head()
# drop the city column from dataframe
df2 = df.drop(['City'], axis=1)
# rename event category. change to 'Response'
df2.rename(columns={'Event Category': 'Response'}, inplace=True)
df2.head()
print(df2)
# remove nulls from data
df2.dropna()
print(df2)
# export altered csv
df2.to_sql('mhpoll.sql', conn,if_exists='replace', index=False)
# Out:
#                                                  Question      Response
# 0                              How often are you stressed  All the time  \
# 1                              How often are you stressed  All the time
# 2                              How often are you stressed  All the time
# 3                              How often are you stressed  All the time
# 4                              How often are you stressed  All the time
# ...                                                   ...           ...
# 136155  What are you most likely to do when you're str...      Work-out
# 136156  What are you most likely to do when you're str...      Work-out
# 136157  What are you most likely to do when you're str...      Work-out
# 136158  What are you most likely to do when you're str...      Work-out
# 136159  What are you most likely to do when you're str...      Work-out
#
#              Region
# 0        California
# 1          Michigan
# 2          Kentucky
# ...

# %%
import pandas as pd
import sqlite3
# set connection to SQLite Database
conn = sqlite3.connect("collegesmhp.csv")
c = conn.cursor()
# open and read file
df = pd.read_csv('collegesmhp.csv')
# print(a1)
df.head()
# drop the city column from dataframe
df2 = df.drop(['Marital status','What is your CGPA?','Timestamp','What is your course?','Your current year of Study'], axis=1)
# # rename event category. change to 'Response'
# df2.rename(columns={'Event Category': 'Response'}, inplace=True)
df2.head()
print(df2)
# remove nulls from data
df2.dropna()
print(df2)
# export altered csv
df2.to_csv('collegesmhp.csv', index=False)
# Out:
#     Choose your gender   Age Do you have Depression? Do you have Anxiety?
# 0               Female  18.0                     Yes                   No  \
# 1                 Male  21.0                      No                  Yes
# 2                 Male  19.0                     Yes                  Yes
# 3               Female  22.0                     Yes                   No
# 4                 Male  23.0                      No                   No
# ..                 ...   ...                     ...                  ...
# 96              Female  21.0                      No                  Yes
# 97                Male  18.0                     Yes                  Yes
# 98              Female  19.0                     Yes                   No
# 99              Female  23.0                      No                   No
# 100               Male  20.0                      No                   No
#
#     Do you have Panic attack? Did you seek any specialist for a treatment?
# ...

# %%
import pandas as pd
import sqlite3
# set connection to SQLite Database
conn = sqlite3.connect("PSMHresOurces2.db")
c = conn.cursor()
# open and read file
df = pd.read_csv('PSMHresOurces2.csv')
# print(a1)
df.head()
 # remove nulls from data
df2 = df.dropna()
df2.rename(columns={'Number of schools providng diagnostic mental health assessments':'NoShcoolsw/MHassessments'}, inplace=True)
df2.rename(columns={'% of schools providing diagnostic mental health assesements':'Percent schoolsw/MHassessments'}, inplace=True)
df2.rename(columns={'No. of school schools poviding treatment':'Noofschoolsprovidingtreatment'}, inplace=True)
df2.rename(columns={'Schools providing diagnostic mental health assessments At school only':'Schoolsw/MHassessmentsatschoolonly'}, inplace=True)
df2.rename(columns={'Schools providing diagnostic mental health assessments outside school only':'Schoolsw/MHassessmentsoutsideschoolonly'}, inplace=True)
df2.rename(columns={'Schools providing diagnostic mental health assessments Both at school and outside of school':'Schoolsw/assessmentsbothinandoutofschool'}, inplace=True)
df2.rename(columns={'Schools providing treatment at school only':'Schoolsprovidingtreatmentatschoolonly'}, inplace=True)
df2.rename(columns={'% of Schools providing treatment':'percofSchoolsprovidingtreatment'}, inplace=True)
df2.rename(columns={'Schools providing treatment Both at school and outside of school':'Schoolsprovidingtreatmentbothatandoutsideofschool'}, inplace=True)
df2.rename(columns={'School characteristic':'Schoolcharacteristic'}, inplace=True)
# print(df2)
df2.head()
# export altered csv
df2.to_sql('PSMHresOurces2.sql', conn,if_exists='replace', index=False)
# Out:
# C:\Users\rodne\AppData\Local\Temp\ipykernel_18396\3090730605.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'Number of schools providng diagnostic mental health assessments':'NoShcoolsw/MHassessments'}, inplace=True)
# C:\Users\rodne\AppData\Local\Temp\ipykernel_18396\3090730605.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'% of schools providing diagnostic mental health assesements':'Percent schoolsw/MHassessments'}, inplace=True)
# C:\Users\rodne\AppData\Local\Temp\ipykernel_18396\3090730605.py:14: SettingWithCopyWarning:
# ...

# %%
conn = sqlite3.connect("PSMHresOurces2.db")
c = conn.cursor()

# %%
df = pd.read_csv('PSMHresOurces2.csv')

# %%
df.head()
# Out:
#        School characteristic
# 0         All public schools  \
# 1                School type
# 2  Traditional public school
# 3             Charter school
# 4                      Level
#
#   Number of schools providng diagnostic mental health assessments
# 0                                             45,600               \
# 1                                                NaN
# 2                                             41,500
# 3                                              4,000
# 4                                                NaN
#
#    % of schools providing diagnostic mental health assesements
# 0                                               54.8            \
# 1                                                NaN
# 2                                               54.2
# 3                                               62.4
# 4                                                NaN
#
#    Schools providing diagnostic mental health assessments At school only
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   School characteristic                                                                        35 non-null     object
#  1   Number of schools providng diagnostic mental health assessments                              27 non-null     object
#  2   % of schools providing diagnostic mental health assesements                                  27 non-null     float64
#  3   Schools providing diagnostic mental health assessments At school only                        27 non-null     float64
#  4   Schools providing diagnostic mental health assessments outside school only                   27 non-null     object
# ...

# %%
df2 = df.dropna()

# %%
df2.to_sql('PSMHresOurces2.sql', conn,if_exists='replace', index=False)
# Out:
# 27
